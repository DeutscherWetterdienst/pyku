# %% [markdown]
# # Resources

# %%
import pyku
from IPython.display import display, Markdown

# %% [markdown]
# ## Test download of all test data

# %%
for id in pyku.list_test_data(include_aliases=False):
    display(Markdown(f"### {id}"))
    display(pyku.resources.get_test_data(id))

# %%
import pyku
pyku.resources.get_test_data('hostrada')

# %% [markdown]
# ## Generation

# %%
pyku.resources.generate_fake_cmip6_data()

# %%
pyku.resources.generate_fake_datasets_with_datetimes_on_disk('/kp/scratch/shaussle/tmp')
